# %% [markdown]
# # Importing necessary Libraries

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense,Activation,Dropout,Conv2D,Flatten,MaxPool2D,Reshape,InputLayer
from tensorflow.keras.applications.resnet50 import ResNet50
from tensorflow.keras.applications.resnet50 import preprocess_input
from tensorflow.keras.preprocessing import image
from tensorflow.keras.preprocessing.image import ImageDataGenerator,load_img,img_to_array
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # 2.Image Augmentation

# %%
path = '/content/drive/MyDrive/Colab Notebooks/flowers'

# %%
train_data_gen = ImageDataGenerator(rescale = 1./255,
                             shear_range = 0.2,
                             zoom_range = 0.2,
                             horizontal_flip = True,
                             validation_split = 0.30)
test_data_gen = ImageDataGenerator(rescale = 1./255,validation_split = 0.30)

# %%
training_set = train_data_gen.flow_from_directory(path,
                                                 target_size=(64,64),
                                                 batch_size=100,
                                                 class_mode='categorical',
                                                 shuffle=True,
                                                 color_mode='rgb',
                                                 subset = 'training')

testing_set = test_data_gen.flow_from_directory(path,
                                                 target_size=(64,64),
                                                 batch_size=100,
                                                 class_mode='categorical',
                                                 shuffle=True,
                                                 color_mode='rgb',
                                                 subset = 'validation')
# Out:
# Found 3024 images belonging to 5 classes.
# Found 1293 images belonging to 5 classes.

# %% [markdown]
# # 3.Create Model

# %%
model = Sequential()

# %% [markdown]
# # 4.Add Layers (Convolution,MaxPooling,Flatten,Dense-(Hidden Layers),Output)

# %%
#convolution and Pooling layer 1
model.add(Conv2D(filters=48,kernel_size=3,activation='relu',input_shape=(64,64,3)))
model.add(MaxPool2D(pool_size=2,strides=2))
model.add(Dropout(0.2))

#convolution and Pooling layer 2
model.add(Conv2D(filters=32,kernel_size=3,activation='relu'))
model.add(MaxPool2D(pool_size=2,strides=2))
model.add(Dropout(0.2))

#Flattening the images
model.add(Flatten())

#Fully Connected layers
model.add(Dense(64,activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(5,activation='softmax'))

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 62, 62, 48)        1344
#
#  max_pooling2d (MaxPooling2D  (None, 31, 31, 48)       0
#  )
#
#  dropout (Dropout)           (None, 31, 31, 48)        0
#
#  conv2d_1 (Conv2D)           (None, 29, 29, 32)        13856
#
#  max_pooling2d_1 (MaxPooling  (None, 14, 14, 32)       0
#  2D)
#
#  dropout_1 (Dropout)         (None, 14, 14, 32)        0
#
#  flatten (Flatten)           (None, 6272)              0
#
#  dense (Dense)               (None, 64)                401472
#
#  dropout_2 (Dropout)         (None, 64)                0
#
#  dense_1 (Dense)             (None, 5)                 325
#
# =================================================================
# Total params: 416,997
# Trainable params: 416,997
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# # 5.Compile The Model

# %%
model.compile(loss='categorical_crossentropy',optimizer='adam',metrics=['accuracy'])

# %% [markdown]
# # 6.Fit The Model

# %%
early_stop = EarlyStopping(monitor='val_accuracy', 
                           patience=5,verbose=1,mode='auto')

lr = ReduceLROnPlateau(monitor='val_accuracy', 
                       factor=0.2,patience=5, 
                       min_lr=0.00001)

callback = [early_stop,lr]

# %% [markdown]
# # Training the Model

# %%
result = model.fit(x=training_set, validation_data=testing_set, epochs=50)
# Out:
# Epoch 1/50
# 31/31 [==============================] - 1982s 64s/step - loss: 1.4570 - accuracy: 0.3337 - val_loss: 1.2932 - val_accuracy: 0.4377
# Epoch 2/50
# 31/31 [==============================] - 17s 553ms/step - loss: 1.2195 - accuracy: 0.4696 - val_loss: 1.1721 - val_accuracy: 0.4803
# Epoch 3/50
# 31/31 [==============================] - 17s 549ms/step - loss: 1.1606 - accuracy: 0.5162 - val_loss: 1.2527 - val_accuracy: 0.4517
# Epoch 4/50
# 31/31 [==============================] - 17s 550ms/step - loss: 1.1480 - accuracy: 0.5228 - val_loss: 1.1611 - val_accuracy: 0.5336
# Epoch 5/50
# 31/31 [==============================] - 17s 547ms/step - loss: 1.0944 - accuracy: 0.5569 - val_loss: 1.1185 - val_accuracy: 0.5460
# Epoch 6/50
# 31/31 [==============================] - 17s 547ms/step - loss: 1.0908 - accuracy: 0.5635 - val_loss: 1.1036 - val_accuracy: 0.5499
# Epoch 7/50
# 31/31 [==============================] - 17s 552ms/step - loss: 1.0493 - accuracy: 0.5714 - val_loss: 1.1278 - val_accuracy: 0.5514
# Epoch 8/50
# 31/31 [==============================] - 17s 550ms/step - loss: 1.0339 - accuracy: 0.5837 - val_loss: 1.1247 - val_accuracy: 0.5383
# Epoch 9/50
# 31/31 [==============================] - 17s 548ms/step - loss: 1.0066 - accuracy: 0.6019 - val_loss: 1.0778 - val_accuracy: 0.5630
# Epoch 10/50
# 31/31 [==============================] - 17s 543ms/step - loss: 0.9642 - accuracy: 0.6181 - val_loss: 1.0311 - val_accuracy: 0.6017
# Epoch 11/50
# 31/31 [==============================] - 17s 546ms/step - loss: 0.9408 - accuracy: 0.6263 - val_loss: 1.0380 - val_accuracy: 0.5901
# Epoch 12/50
# 31/31 [==============================] - 17s 546ms/step - loss: 0.9123 - accuracy: 0.6409 - val_loss: 1.0590 - val_accuracy: 0.5955
# Epoch 13/50
# 31/31 [==============================] - 17s 549ms/step - loss: 0.9018 - accuracy: 0.6389 - val_loss: 1.0150 - val_accuracy: 0.6110
# Epoch 14/50
# 31/31 [==============================] - 17s 554ms/step - loss: 0.8826 - accuracy: 0.6571 - val_loss: 0.9838 - val_accuracy: 0.6342
# Epoch 15/50
# 31/31 [==============================] - 17s 543ms/step - loss: 0.8728 - accuracy: 0.6571 - val_loss: 0.9950 - val_accuracy: 0.6218
# Epoch 16/50
# 31/31 [==============================] - 17s 552ms/step - loss: 0.8639 - accuracy: 0.6660 - val_loss: 0.9802 - val_accuracy: 0.6481
# Epoch 17/50
# 31/31 [==============================] - 17s 562ms/step - loss: 0.8321 - accuracy: 0.6620 - val_loss: 0.9918 - val_accuracy: 0.6288
# Epoch 18/50
# 31/31 [==============================] - 17s 551ms/step - loss: 0.8212 - accuracy: 0.6792 - val_loss: 0.9499 - val_accuracy: 0.6466
# Epoch 19/50
# 31/31 [==============================] - 17s 547ms/step - loss: 0.7858 - accuracy: 0.6885 - val_loss: 0.9446 - val_accuracy: 0.6551
# Epoch 20/50
# 31/31 [==============================] - 17s 548ms/step - loss: 0.7655 - accuracy: 0.7021 - val_loss: 0.9519 - val_accuracy: 0.6466
# Epoch 21/50
# 31/31 [==============================] - 17s 552ms/step - loss: 0.7827 - accuracy: 0.6911 - val_loss: 0.9438 - val_accuracy: 0.6497
# Epoch 22/50
# 31/31 [==============================] - 17s 547ms/step - loss: 0.7623 - accuracy: 0.6978 - val_loss: 0.9435 - val_accuracy: 0.6543
# Epoch 23/50
# 31/31 [==============================] - 17s 544ms/step - loss: 0.7521 - accuracy: 0.7100 - val_loss: 0.9485 - val_accuracy: 0.6442
# Epoch 24/50
# 31/31 [==============================] - 17s 546ms/step - loss: 0.7337 - accuracy: 0.7156 - val_loss: 0.9521 - val_accuracy: 0.6582
# Epoch 25/50
# 31/31 [==============================] - 17s 551ms/step - loss: 0.7033 - accuracy: 0.7321 - val_loss: 0.9920 - val_accuracy: 0.6543
# Epoch 26/50
# 31/31 [==============================] - 17s 545ms/step - loss: 0.7184 - accuracy: 0.7262 - val_loss: 0.9905 - val_accuracy: 0.6543
# Epoch 27/50
# 31/31 [==============================] - 17s 548ms/step - loss: 0.6920 - accuracy: 0.7371 - val_loss: 0.9529 - val_accuracy: 0.6574
# Epoch 28/50
# 31/31 [==============================] - 17s 549ms/step - loss: 0.6882 - accuracy: 0.7325 - val_loss: 0.9972 - val_accuracy: 0.6311
# Epoch 29/50
# 31/31 [==============================] - 17s 547ms/step - loss: 0.6828 - accuracy: 0.7401 - val_loss: 0.9695 - val_accuracy: 0.6504
# Epoch 30/50
# 31/31 [==============================] - 17s 546ms/step - loss: 0.6656 - accuracy: 0.7417 - val_loss: 0.9867 - val_accuracy: 0.6373
# Epoch 31/50
# 31/31 [==============================] - 17s 551ms/step - loss: 0.6508 - accuracy: 0.7526 - val_loss: 0.9260 - val_accuracy: 0.6582
# Epoch 32/50
# 31/31 [==============================] - 17s 551ms/step - loss: 0.6438 - accuracy: 0.7467 - val_loss: 0.8944 - val_accuracy: 0.6682
# Epoch 33/50
# 31/31 [==============================] - 17s 546ms/step - loss: 0.6340 - accuracy: 0.7513 - val_loss: 1.0099 - val_accuracy: 0.6342
# Epoch 34/50
# 31/31 [==============================] - 17s 549ms/step - loss: 0.6350 - accuracy: 0.7553 - val_loss: 0.9457 - val_accuracy: 0.6643
# Epoch 35/50
# 31/31 [==============================] - 17s 561ms/step - loss: 0.6159 - accuracy: 0.7636 - val_loss: 0.8814 - val_accuracy: 0.6605
# Epoch 36/50
# 31/31 [==============================] - 17s 555ms/step - loss: 0.6302 - accuracy: 0.7550 - val_loss: 0.9177 - val_accuracy: 0.6775
# Epoch 37/50
# 31/31 [==============================] - 17s 546ms/step - loss: 0.6030 - accuracy: 0.7636 - val_loss: 0.9135 - val_accuracy: 0.6690
# Epoch 38/50
# 31/31 [==============================] - 17s 551ms/step - loss: 0.5916 - accuracy: 0.7695 - val_loss: 0.8999 - val_accuracy: 0.6783
# Epoch 39/50
# 31/31 [==============================] - 17s 544ms/step - loss: 0.5986 - accuracy: 0.7566 - val_loss: 1.0032 - val_accuracy: 0.6350
# Epoch 40/50
# 31/31 [==============================] - 17s 558ms/step - loss: 0.5790 - accuracy: 0.7725 - val_loss: 0.9390 - val_accuracy: 0.6814
# Epoch 41/50
# 31/31 [==============================] - 17s 550ms/step - loss: 0.5655 - accuracy: 0.7735 - val_loss: 0.8965 - val_accuracy: 0.6829
# Epoch 42/50
# 31/31 [==============================] - 17s 549ms/step - loss: 0.5657 - accuracy: 0.7814 - val_loss: 0.9788 - val_accuracy: 0.6698
# Epoch 43/50
# 31/31 [==============================] - 17s 546ms/step - loss: 0.5712 - accuracy: 0.7778 - val_loss: 0.9788 - val_accuracy: 0.6582
# Epoch 44/50
# 31/31 [==============================] - 17s 544ms/step - loss: 0.5703 - accuracy: 0.7761 - val_loss: 0.9533 - val_accuracy: 0.6790
# Epoch 45/50
# 31/31 [==============================] - 17s 547ms/step - loss: 0.5782 - accuracy: 0.7751 - val_loss: 0.9369 - val_accuracy: 0.6651
# Epoch 46/50
# 31/31 [==============================] - 17s 541ms/step - loss: 0.5799 - accuracy: 0.7725 - val_loss: 0.9609 - val_accuracy: 0.6690
# Epoch 47/50
# 31/31 [==============================] - 17s 549ms/step - loss: 0.5356 - accuracy: 0.7946 - val_loss: 0.9535 - val_accuracy: 0.6775
# Epoch 48/50
# 31/31 [==============================] - 17s 537ms/step - loss: 0.5315 - accuracy: 0.7973 - val_loss: 0.9319 - val_accuracy: 0.6783
# Epoch 49/50
# 31/31 [==============================] - 17s 539ms/step - loss: 0.5084 - accuracy: 0.8016 - val_loss: 0.9464 - val_accuracy: 0.6736
# Epoch 50/50
# 31/31 [==============================] - 17s 544ms/step - loss: 0.5079 - accuracy: 0.8016 - val_loss: 0.9568 - val_accuracy: 0.6767

# %% [markdown]
# # Loss and Accuracy check using plot

# %%
#plot the loss
plt.plot(result.history['loss'], label='train loss')
plt.plot(result.history['val_loss'], label='val loss')
plt.legend()
plt.show()

# plot the accuracy
plt.plot(result.history['accuracy'], label='train acc')
plt.plot(result.history['val_accuracy'], label='val acc')
plt.legend()
plt.show()

# %% [markdown]
# # 7.Save the Model

# %%
model.save('flower.h5')

# %% [markdown]
# # 8.Test The Model

# %%
training_set.class_indices
# Out:
# {'daisy': 0, 'dandelion': 1, 'rose': 2, 'sunflower': 3, 'tulip': 4}

# %%
classes = ['Daisy','Dandelion','Rose','Sunflower','Tulip'] 
def testing(img):
    img = image.load_img(img,target_size=(64,64)) 
    x = image.img_to_array(img) 
    x = np.expand_dims(x,axis=0) 
    pred = np.argmax(model.predict(x)) 
    return print("Predicted class as:",classes[pred])

def img_show(img):
    img1 = image.load_img(img,target_size=(64,64)) 
    plt.imshow(img1)

# %%
#test1
img_show('/content/drive/MyDrive/Colab Notebooks/flowers/daisy/102841525_bd6628ae3c.jpg')
testing('/content/drive/MyDrive/Colab Notebooks/flowers/daisy/102841525_bd6628ae3c.jpg')
# Out:
# Predicted class as: Daisy

# %%
#test2
img_show('/content/drive/MyDrive/Colab Notebooks/flowers/dandelion/26.jpg')
testing('/content/drive/MyDrive/Colab Notebooks/flowers/dandelion/26.jpg')
# Out:
# Predicted class as: Dandelion

# %%
#test3
img_show('/content/drive/MyDrive/Colab Notebooks/flowers/rose/27.jpg')
testing('/content/drive/MyDrive/Colab Notebooks/flowers/rose/27.jpg')
# Out:
# Predicted class as: Rose

# %%
#test4
img_show('/content/drive/MyDrive/Colab Notebooks/flowers/sunflower/1022552002_2b93faf9e7_n.jpg')
testing('/content/drive/MyDrive/Colab Notebooks/flowers/sunflower/1022552002_2b93faf9e7_n.jpg')
# Out:
# Predicted class as: Sunflower

# %%
#test5
img_show('/content/drive/MyDrive/Colab Notebooks/flowers/tulip/10128546863_8de70c610d.jpg')
testing('/content/drive/MyDrive/Colab Notebooks/flowers/tulip/10128546863_8de70c610d.jpg')
# Out:
# Predicted class as: Tulip
