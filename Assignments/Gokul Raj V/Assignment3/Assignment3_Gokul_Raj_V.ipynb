# %% [markdown]
# # Importing necessary Libraries

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense,Activation,Dropout,Conv2D,Flatten,MaxPool2D,Reshape,InputLayer
from tensorflow.keras.applications.resnet50 import ResNet50
from tensorflow.keras.applications.resnet50 import preprocess_input
from tensorflow.keras.preprocessing import image
from tensorflow.keras.preprocessing.image import ImageDataGenerator,load_img,img_to_array
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # 2.Image Augmentation

# %%
path = '/content/drive/MyDrive/Colab Notebooks/flowers'

# %%
train_data_gen = ImageDataGenerator(rescale = 1./255,
                             shear_range = 0.2,
                             zoom_range = 0.2,
                             horizontal_flip = True,
                             validation_split = 0.30)
test_data_gen = ImageDataGenerator(rescale = 1./255,validation_split = 0.30)

# %%
training_set = train_data_gen.flow_from_directory(path,
                                                 target_size=(64,64),
                                                 batch_size=100,
                                                 class_mode='categorical',
                                                 shuffle=True,
                                                 color_mode='rgb',
                                                 subset = 'training')

testing_set = test_data_gen.flow_from_directory(path,
                                                 target_size=(64,64),
                                                 batch_size=100,
                                                 class_mode='categorical',
                                                 shuffle=True,
                                                 color_mode='rgb',
                                                 subset = 'validation')
# Out:
# Found 3031 images belonging to 5 classes.
# Found 1296 images belonging to 5 classes.

# %% [markdown]
# # 3.Create Model

# %%
model = Sequential()

# %% [markdown]
# # 4.Add Layers (Convolution,MaxPooling,Flatten,Dense-(Hidden Layers),Output)

# %%
#convolution and Pooling layer 1
model.add(Conv2D(filters=48,kernel_size=3,activation='relu',input_shape=(64,64,3)))
model.add(MaxPool2D(pool_size=2,strides=2))
model.add(Dropout(0.2))

#convolution and Pooling layer 2
model.add(Conv2D(filters=32,kernel_size=3,activation='relu'))
model.add(MaxPool2D(pool_size=2,strides=2))
model.add(Dropout(0.2))

#Flattening the images
model.add(Flatten())

#Fully Connected layers
model.add(Dense(64,activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(5,activation='softmax'))

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 62, 62, 48)        1344
#
#  max_pooling2d (MaxPooling2D  (None, 31, 31, 48)       0
#  )
#
#  dropout (Dropout)           (None, 31, 31, 48)        0
#
#  conv2d_1 (Conv2D)           (None, 29, 29, 32)        13856
#
#  max_pooling2d_1 (MaxPooling  (None, 14, 14, 32)       0
#  2D)
#
#  dropout_1 (Dropout)         (None, 14, 14, 32)        0
#
#  flatten (Flatten)           (None, 6272)              0
#
#  dense (Dense)               (None, 64)                401472
#
#  dropout_2 (Dropout)         (None, 64)                0
#
#  dense_1 (Dense)             (None, 5)                 325
#
# =================================================================
# Total params: 416,997
# Trainable params: 416,997
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# # 5.Compile The Model

# %%
model.compile(loss='categorical_crossentropy',optimizer='adam',metrics=['accuracy'])

# %% [markdown]
# # 6.Fit The Model

# %%
early_stop = EarlyStopping(monitor='val_accuracy', 
                           patience=5,verbose=1,mode='auto')

lr = ReduceLROnPlateau(monitor='val_accuracy', 
                       factor=0.2,patience=5, 
                       min_lr=0.00001)

callback = [early_stop,lr]

# %% [markdown]
# # Training the Model

# %%
result = model.fit(x=training_set, validation_data=testing_set, epochs=50)
# Out:
# Epoch 1/50
# 31/31 [==============================] - 951s 31s/step - loss: 1.5096 - accuracy: 0.3345 - val_loss: 1.3648 - val_accuracy: 0.4005
# Epoch 2/50
# 31/31 [==============================] - 17s 536ms/step - loss: 1.2919 - accuracy: 0.4467 - val_loss: 1.2213 - val_accuracy: 0.4985
# Epoch 3/50
# 31/31 [==============================] - 16s 530ms/step - loss: 1.1900 - accuracy: 0.5054 - val_loss: 1.1470 - val_accuracy: 0.5386
# Epoch 4/50
# 31/31 [==============================] - 17s 563ms/step - loss: 1.1270 - accuracy: 0.5272 - val_loss: 1.1417 - val_accuracy: 0.5540
# Epoch 5/50
# 31/31 [==============================] - 16s 532ms/step - loss: 1.0839 - accuracy: 0.5648 - val_loss: 1.1268 - val_accuracy: 0.5486
# Epoch 6/50
# 31/31 [==============================] - 16s 535ms/step - loss: 1.0402 - accuracy: 0.5833 - val_loss: 1.0908 - val_accuracy: 0.5779
# Epoch 7/50
# 31/31 [==============================] - 16s 532ms/step - loss: 0.9935 - accuracy: 0.6051 - val_loss: 1.0910 - val_accuracy: 0.5826
# Epoch 8/50
# 31/31 [==============================] - 16s 533ms/step - loss: 0.9533 - accuracy: 0.6262 - val_loss: 1.0183 - val_accuracy: 0.6096
# Epoch 9/50
# 31/31 [==============================] - 16s 529ms/step - loss: 0.9290 - accuracy: 0.6377 - val_loss: 1.0048 - val_accuracy: 0.6026
# Epoch 10/50
# 31/31 [==============================] - 16s 535ms/step - loss: 0.9069 - accuracy: 0.6565 - val_loss: 1.0129 - val_accuracy: 0.6080
# Epoch 11/50
# 31/31 [==============================] - 16s 531ms/step - loss: 0.8872 - accuracy: 0.6480 - val_loss: 0.9993 - val_accuracy: 0.6204
# Epoch 12/50
# 31/31 [==============================] - 16s 531ms/step - loss: 0.8746 - accuracy: 0.6565 - val_loss: 0.9594 - val_accuracy: 0.6265
# Epoch 13/50
# 31/31 [==============================] - 16s 535ms/step - loss: 0.8486 - accuracy: 0.6704 - val_loss: 0.9477 - val_accuracy: 0.6505
# Epoch 14/50
# 31/31 [==============================] - 16s 532ms/step - loss: 0.8220 - accuracy: 0.6895 - val_loss: 0.9501 - val_accuracy: 0.6505
# Epoch 15/50
# 31/31 [==============================] - 16s 531ms/step - loss: 0.7967 - accuracy: 0.6928 - val_loss: 0.9676 - val_accuracy: 0.6435
# Epoch 16/50
# 31/31 [==============================] - 17s 566ms/step - loss: 0.7654 - accuracy: 0.7064 - val_loss: 0.9755 - val_accuracy: 0.6420
# Epoch 17/50
# 31/31 [==============================] - 17s 544ms/step - loss: 0.7568 - accuracy: 0.7153 - val_loss: 0.9479 - val_accuracy: 0.6620
# Epoch 18/50
# 31/31 [==============================] - 16s 534ms/step - loss: 0.7461 - accuracy: 0.7123 - val_loss: 0.8925 - val_accuracy: 0.6636
# Epoch 19/50
# 31/31 [==============================] - 17s 539ms/step - loss: 0.7401 - accuracy: 0.7202 - val_loss: 0.8991 - val_accuracy: 0.6698
# Epoch 20/50
# 31/31 [==============================] - 16s 531ms/step - loss: 0.7264 - accuracy: 0.7215 - val_loss: 0.9885 - val_accuracy: 0.6474
# Epoch 21/50
# 31/31 [==============================] - 16s 531ms/step - loss: 0.7012 - accuracy: 0.7377 - val_loss: 0.9030 - val_accuracy: 0.6628
# Epoch 22/50
# 31/31 [==============================] - 16s 527ms/step - loss: 0.7077 - accuracy: 0.7265 - val_loss: 1.0002 - val_accuracy: 0.6520
# Epoch 23/50
# 31/31 [==============================] - 16s 532ms/step - loss: 0.6745 - accuracy: 0.7384 - val_loss: 1.0167 - val_accuracy: 0.6350
# Epoch 24/50
# 31/31 [==============================] - 16s 533ms/step - loss: 0.6594 - accuracy: 0.7384 - val_loss: 0.9441 - val_accuracy: 0.6489
# Epoch 25/50
# 31/31 [==============================] - 16s 529ms/step - loss: 0.6150 - accuracy: 0.7687 - val_loss: 0.9107 - val_accuracy: 0.6698
# Epoch 26/50
# 31/31 [==============================] - 17s 538ms/step - loss: 0.6336 - accuracy: 0.7575 - val_loss: 0.9886 - val_accuracy: 0.6497
# Epoch 27/50
# 31/31 [==============================] - 16s 531ms/step - loss: 0.6276 - accuracy: 0.7658 - val_loss: 0.9398 - val_accuracy: 0.6659
# Epoch 28/50
# 31/31 [==============================] - 16s 531ms/step - loss: 0.5904 - accuracy: 0.7753 - val_loss: 0.9246 - val_accuracy: 0.6636
# Epoch 29/50
# 31/31 [==============================] - 17s 558ms/step - loss: 0.6056 - accuracy: 0.7658 - val_loss: 0.9367 - val_accuracy: 0.6767
# Epoch 30/50
# 31/31 [==============================] - 16s 535ms/step - loss: 0.5805 - accuracy: 0.7806 - val_loss: 0.9068 - val_accuracy: 0.6813
# Epoch 31/50
# 31/31 [==============================] - 16s 530ms/step - loss: 0.5807 - accuracy: 0.7700 - val_loss: 0.9265 - val_accuracy: 0.6721
# Epoch 32/50
# 31/31 [==============================] - 16s 533ms/step - loss: 0.5512 - accuracy: 0.7961 - val_loss: 0.9289 - val_accuracy: 0.6798
# Epoch 33/50
# 31/31 [==============================] - 16s 530ms/step - loss: 0.5340 - accuracy: 0.8030 - val_loss: 1.1163 - val_accuracy: 0.6505
# Epoch 34/50
# 31/31 [==============================] - 16s 533ms/step - loss: 0.5566 - accuracy: 0.7836 - val_loss: 0.9211 - val_accuracy: 0.6836
# Epoch 35/50
# 31/31 [==============================] - 16s 532ms/step - loss: 0.5220 - accuracy: 0.8027 - val_loss: 0.9807 - val_accuracy: 0.6674
# Epoch 36/50
# 31/31 [==============================] - 17s 543ms/step - loss: 0.5388 - accuracy: 0.7945 - val_loss: 1.0807 - val_accuracy: 0.6551
# Epoch 37/50
# 31/31 [==============================] - 16s 533ms/step - loss: 0.5183 - accuracy: 0.8057 - val_loss: 0.9301 - val_accuracy: 0.6914
# Epoch 38/50
# 31/31 [==============================] - 16s 528ms/step - loss: 0.4964 - accuracy: 0.8156 - val_loss: 0.9834 - val_accuracy: 0.6597
# Epoch 39/50
# 31/31 [==============================] - 16s 530ms/step - loss: 0.4825 - accuracy: 0.8192 - val_loss: 0.9782 - val_accuracy: 0.6821
# Epoch 40/50
# 31/31 [==============================] - 16s 530ms/step - loss: 0.5132 - accuracy: 0.8044 - val_loss: 1.0439 - val_accuracy: 0.6667
# Epoch 41/50
# 31/31 [==============================] - 17s 561ms/step - loss: 0.5163 - accuracy: 0.8159 - val_loss: 1.0246 - val_accuracy: 0.6674
# Epoch 42/50
# 31/31 [==============================] - 16s 528ms/step - loss: 0.4710 - accuracy: 0.8301 - val_loss: 1.0305 - val_accuracy: 0.6782
# Epoch 43/50
# 31/31 [==============================] - 16s 528ms/step - loss: 0.4788 - accuracy: 0.8152 - val_loss: 0.9676 - val_accuracy: 0.6790
# Epoch 44/50
# 31/31 [==============================] - 16s 537ms/step - loss: 0.4615 - accuracy: 0.8298 - val_loss: 1.0117 - val_accuracy: 0.6860
# Epoch 45/50
# 31/31 [==============================] - 16s 530ms/step - loss: 0.4459 - accuracy: 0.8327 - val_loss: 1.0362 - val_accuracy: 0.6860
# Epoch 46/50
# 31/31 [==============================] - 16s 528ms/step - loss: 0.4488 - accuracy: 0.8317 - val_loss: 1.0466 - val_accuracy: 0.6929
# Epoch 47/50
# 31/31 [==============================] - 16s 528ms/step - loss: 0.4257 - accuracy: 0.8446 - val_loss: 1.0765 - val_accuracy: 0.6659
# Epoch 48/50
# 31/31 [==============================] - 16s 532ms/step - loss: 0.4242 - accuracy: 0.8377 - val_loss: 1.0145 - val_accuracy: 0.6821
# Epoch 49/50
# 31/31 [==============================] - 16s 527ms/step - loss: 0.4039 - accuracy: 0.8535 - val_loss: 1.0375 - val_accuracy: 0.6821
# Epoch 50/50
# 31/31 [==============================] - 16s 530ms/step - loss: 0.4224 - accuracy: 0.8397 - val_loss: 1.1033 - val_accuracy: 0.6813

# %% [markdown]
# # Loss and Accuracy check using plot

# %%
#plot the loss
plt.plot(result.history['loss'], label='train loss')
plt.plot(result.history['val_loss'], label='val loss')
plt.legend()
plt.show()

# plot the accuracy
plt.plot(result.history['accuracy'], label='train acc')
plt.plot(result.history['val_accuracy'], label='val acc')
plt.legend()
plt.show()

# %% [markdown]
# # 7.Save the Model

# %%
model.save('flower.h5')

# %% [markdown]
# # 8.Test The Model

# %%
training_set.class_indices
# Out:
# {'daisy': 0, 'dandelion': 1, 'rose': 2, 'sunflower': 3, 'tulip': 4}

# %%
classes = ['Daisy','Dandelion','Rose','Sunflower','Tulip'] 
def testing(img):
    img = image.load_img(img,target_size=(64,64)) 
    x = image.img_to_array(img) 
    x = np.expand_dims(x,axis=0) 
    pred = np.argmax(model.predict(x)) 
    return print("Predicted class as:",classes[pred])

def img_show(img):
    img1 = image.load_img(img,target_size=(64,64)) 
    plt.imshow(img1)

# %%
#test1
img_show('/content/drive/MyDrive/Colab Notebooks/flowers/daisy/31.jpg')
testing('/content/drive/MyDrive/Colab Notebooks/flowers/daisy/31.jpg')
# Out:
# Predicted class as: Daisy

# %%
#test2
img_show('/content/drive/MyDrive/Colab Notebooks/flowers/dandelion/1.jpg')
testing('/content/drive/MyDrive/Colab Notebooks/flowers/dandelion/1.jpg')
# Out:
# Predicted class as: Dandelion

# %%
#test3
img_show('/content/drive/MyDrive/Colab Notebooks/flowers/rose/10.jpg')
testing('/content/drive/MyDrive/Colab Notebooks/flowers/rose/10.jpg')
# Out:
# Predicted class as: Rose

# %%
#test4
img_show('/content/drive/MyDrive/Colab Notebooks/flowers/sunflower/20.jpg')
testing('/content/drive/MyDrive/Colab Notebooks/flowers/sunflower/20.jpg')
# Out:
# Predicted class as: Sunflower

# %%
#test5
img_show('/content/drive/MyDrive/Colab Notebooks/flowers/tulip/88.jpg')
testing('/content/drive/MyDrive/Colab Notebooks/flowers/tulip/88.jpg')
# Out:
# Predicted class as: Tulip
